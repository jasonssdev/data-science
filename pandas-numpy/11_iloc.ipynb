# %%
import pandas as pd

# %%
df_books = pd.read_csv("./data/bestsellers with categories.csv", sep=",", header=0, names=['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df_hp = pd.read_json("./data/HPCharactersDataRaw.json")
df_hp
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
df_hp = pd.read_json("./data/HPCharactersDataRaw.json", typ="Series")
df_hp
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# filter by index
df_books[0:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# filter by one column
df_books["Genre"]
# Out:
# 0      Non Fiction
# 1          Fiction
# 2      Non Fiction
# 3          Fiction
# 4      Non Fiction
#           ...
# 545        Fiction
# 546    Non Fiction
# 547    Non Fiction
# 548    Non Fiction
# 549    Non Fiction
# Name: Genre, Length: 550, dtype: object

# %%
# filter by columns
df_books[["Genre", "Author", "Name"]]
# Out:
#            Genre                    Author  \
# 0    Non Fiction                  JJ Smith
# 1        Fiction              Stephen King
# 2    Non Fiction        Jordan B. Peterson
# 3        Fiction             George Orwell
# 4    Non Fiction  National Geographic Kids
# ..           ...                       ...
# 545      Fiction               Jeff Kinney
# 546  Non Fiction               Jen Sincero
# 547  Non Fiction               Jen Sincero
# 548  Non Fiction               Jen Sincero
# 549  Non Fiction               Jen Sincero
#
#                                                   Name
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# ...

# %%
df_books.loc[0:4]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# complex filer with loc
df_books.loc[0:4, ["Author", "Name"]]
# Out:
#                      Author                                               Name
# 0                  JJ Smith                      10-Day Green Smoothie Cleanse
# 1              Stephen King                                  11/22/63: A Novel
# 2        Jordan B. Peterson            12 Rules for Life: An Antidote to Chaos
# 3             George Orwell                             1984 (Signet Classics)
# 4  National Geographic Kids  5,000 Awesome Facts (About Everything!) (Natio...

# %%
# complex filer with loc
df_books.loc[:, ["Author"]] == "JJ Smith"
# Out:
#      Author
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %%
# complex filer with loc
df_books.loc[0:50, ["Reviews"]] * -1
# Out:
#     Reviews
# 0    -17350
# 1     -2052
# 2    -18979
# 3    -21424
# 4     -7665
# 5    -12643
# 6    -19735
# 7    -19699
# 8     -5983
# 9    -23848
# 10   -23848
# 11     -460
# 12    -4149
# 13    -5153
# 14    -5013
# 15    -2313
# 16    -2925
# 17    -2951
# 18    -2426
# 19    -9198
# 20   -36348
# 21   -36348
# 22    -6310
# 23   -15921
# 24   -12159
# 25     -798
# 26    -9374
# 27     -491
# 28    -5360
# 29    -1909
# 30    -1296
# 31     -615
# 32   -61133
# 33   -61133
# 34   -11113
# 35   -10070
# 36   -10070
# 37    -3729
# 38    -9769
# 39     -471
# 40   -14344
# 41   -14344
# 42    -4505
# 43   -10369
# 44   -16244
# 45    -2884
# 46   -22614
# 47   -22614
# 48   -22614
# 49    -4761
# 50    -1542

# %%
# filter by index
df_books.iloc[:, 0:3]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ...

# %% [markdown]
# ### loc use headers and iloc use index
